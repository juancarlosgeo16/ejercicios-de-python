# %% [markdown]
# ## Evaluación 1

# %% [markdown]
# **Ejercicio 1:**
#
# %%latex
# \begin{eqnarray}
# \frac{2^3+10/5}{15}
# \end{eqnarray}

# %%
(2**3 + 10/5)/15
# Out:
# 0.6666666666666666

# %% [markdown]
# **Ejercicio 2:**
#
# Revertir la palabra 'Hello world'.

# %%
A = " hello "
B = " world "


init = [A, B]
palabra = init[0] + init[1]
init.reverse()
palabra2 == palabra
palabra2
# Out:
# ' world  hello '

# %% [markdown]
# **Ejercicio 3:**
#
# Cree la siguiente lista [0,0,0] de 2 formas distintas.

# %%
a = [0,0,0]
b = [[0],0,0]
c = [0,[0],[0]]

# %% [markdown]
# **Ejercicio 4:**
#
# Cambie la palabra 'hello' por 'goodbye'

# %%
lista = [1, 2, [3, 4, ('hello')]]
lista[2][2]

lista[2][2] = "goodbye"
lista
# Out:
# [1, 2, [3, 4, 'goodbye']]

# %% [markdown]
# **Ejercicio 5:**
#
# Obtenga la palabra 'hello' de los siguiente ejemplos

# %%
d1 = {'simple_key':'hello'}
d1["simple_key"]
# Out:
# 'hello'

# %%
d2 = {'k1':{'k2':'hello'}}
d2["k1"]["k2"]
# Out:
# 'hello'

# %%
estacion = {
    "cate": "CO",
    "cod": "105062",
    "cod_old": "000349",
    "estado": "DIFERIDO",
    "ico": "M",
    "lat": -5.67175,
    "lon": -78.89767,
    "nom": "hello"
}

estacion["nom"]
# Out:
# 'hello'

# %% [markdown]
# **Ejercicio 6:**
#
# ¿Cuantos números por encima de 20 existen en la siguiente lista. Resuelvalo usando for.

# %%
lista = [10, 40, 60, 70, 80]
for i in range(len(lista)):
  if lista[i] > 20:
    print (lista[i])
  
#no me sale, alli me quede
# Out:
# 40
# 60
# 70
# 80

# %% [markdown]
# **Ejercicio 7:**
#
# Crear un programa que mencione si un número es positivo, negativo o cero.

# %%
num = [0, -2, 4, 5, 6]
a = num [4]

if a!= 0:
  if a > 0:
    print("it's a possitive number")
  else:
    print("it's a number negative")
else:
  print ("it's a number cero")
# Out:
# it's a possitive number

# %% [markdown]
# **Ejercicio 8:**
#
# Crear un programa al que se le ingrese grados Kelvin y devuelva Farenheit y Celcius.

# %%
gradoskelvin= "200" 

K = int(gradoskelvin)
C = K - 273.15
F = K * 1.8-459.67

print ("gradosfarenheit =",F) 
print ("gradoscelsius =",C)
# Out:
# gradosfarenheit = -99.67000000000002
# gradoscelsius = -73.14999999999998
